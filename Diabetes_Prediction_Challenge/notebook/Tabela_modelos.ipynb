# %% [markdown]
# # Tabela modelos

# %% [markdown]
# | Modelo | Árvore? | Complexidade Estrutural do Modelo | Estrutura da Relação | Escala do Dataset | Escalonamento Necessário? | Suporte a Categóricas | Complexidade Computacional | Escalabilidade (Big Data) | Sensibilidade a Hiperparâmetros | Paralelização |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | **OLS (Mínimos Quadrados)** | Não | **Baixa: Poucos coeficientes lineares** | Linear | Pequeno / Médio | Sim | Não | Baixa ($O(n \cdot p^2)$) | Baixa | **Baixa** | Parcial |
# | **KNN** | Não | Baixa: Baseado em vizinhança local | **Estrutura local** | Pequeno | Sim | Não | Muito Alta no Teste | Muito Baixa | Baixa | Parcial |
# | **Logistic Regression** | Não | Baixa: Pesos lineares (função logística) | Linear (probabilística) | **Médio / Grande** | Sim | Não | **Baixa ($O(n \cdot p)$)** | **Alta (via SGD)** | Baixa | **Sim** |
# | **SVM (Kernel Linear)** | Não | Baixa: Hiperplano com vetores de suporte | Linear | Médio | Sim | Não | Média ($O(n^2 \dots n^3)$) | Baixa / Média | Alta | Parcial |
# | **SVM (Kernel RBF)** | Não | Alta: Expansão via kernel implícito | Não linear (kernel) | Pequeno | Sim | Não | Muito Alta ($O(n^3)$) | Muito Baixa | Obrigatória | Não |
# |-|
# | **Decision Tree** | Sim | **Média: Conjunto de regras hierárquicas** | **Não linear (regras)** | Pequeno / Médio | **Não** | Nativo (algumas libs) | **Baixa ($O(n \cdot p \cdot \log n)$)** | Média | Alta | Não |
# | **Random Forest** | Sim | Alta: Ensemble de múltiplas árvores | Não linear complexa | Médio / Grande | Não | Não | Alta (Paralelizável) | Média / Alta | **Baixa** | **Sim** |
# | **AdaBoost** | Sim | Alta: Sequência de classificadores ponderados | Não linear (boosting) | Médio | Não | Não | Média (Sequencial) | Baixa / Média | Alta | Não |
# | **XGBoost** | Sim | Muito Alta: Soma sequencial de árvores | Não linear complexa | Médio / Grande | Não | Parcial | Alta (Sequencial) | Alta | Obrigatória | Parcial |
# | **LightGBM (LGBM)** | Sim | Muito Alta: Muitas árvores leaf-wise | Não linear complexa | **Grande / Muito Grande** | Não | Nativo (Excelente) | **Média (Otimizado RAM)** | **Altíssima** | Alta | **Sim** |
# | **CatBoost** | Sim | Muito Alta: Ensemble profundo de árvores simétricas | Não linear complexa | Grande | Não | **Nativo (Líder)** | Alta treino / Baixa uso | Alta | **Baixa** | Parcial |
