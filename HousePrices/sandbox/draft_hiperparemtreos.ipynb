# %% [markdown]
# ## hiperparametros

# %%
# # #busca hiperparametros
# cv = KFold(n_splits=5, shuffle=True, random_state=42)

# # # Parâmetros para o modelo Ridge
# param_dist_lasso = {
#     'alpha': np.logspace(-3, 2, 40),
#     'max_iter': [2000, 5000],
#     'tol': [1e-4, 1e-3],
#     'fit_intercept': [True, False],
#     'selection': ['cyclic', 'random'],
# }
# # Cria o modelo Ridge
# lasso= Lasso()

# # RandomizedSearchCV para Ridge
# rand_lasso = RandomizedSearchCV(
#     estimator=lasso,
#     param_distributions=param_dist_lasso,
#     n_iter=75,                   
#     cv=cv,
#     scoring='neg_mean_squared_error',
#     random_state=42,
#     n_jobs=-1,
#     verbose=1,
#     error_score='raise'
# )

# # Pipeline com preprocessador e modelo
# model_RSearch_lasso = Pipeline([
#     ('preprocess', preprocessador0), 
#     ('model', rand_lasso)
# ])

# X=df_train.drop(['Id', 'SalePrice'], axis=1)
# y=np.log1p(df_train['SalePrice'])
# start_time = time.time()

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# model_RSearch_lasso.fit(X_train,y_train)
# end_time = time.time()
# print(f"⏱️ Tempo de execução: {end_time - start_time:.2f} segundos")
#rand_lasso.best_params_
